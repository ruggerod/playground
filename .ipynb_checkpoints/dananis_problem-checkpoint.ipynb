# %%
import numpy as np
from scipy.misc import factorial
from scipy.optimize import brentq
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %% [markdown]
# # Problema
#
# Sia X un importo iniziale fissato. Qual è la successione $p_n$ (con $n = 0,..,N-1$) di interessi percentuali che permette di ottenere un importo Y partendo da X?
#
# Ovvero, trovare la successione che soddisfa la seguente equazione:
# \begin{equation}
# \prod_{n=0}^{N-1} (1+p_n) - \frac{Y}{X} = 0 \ \ \ \ (1)
# \end{equation}
#
# Nel caso semplice di tasso fisso, ovvero $p_n = p \ (n=0,..,N-1)$, si ha
# \begin{equation}
# X(1+p)^N = Y \ \ \ \ (2)
# \end{equation}

# %% [markdown]
# ## Costanti

# %%
X = 10.
Y = 1000.
N = 365
alphas = [-1., -0.8, -0.6, -0.4, -0.2] # slopes of the power-law p_n = const * n^alpha

# %% [markdown]
# ## Calcolatore

# %%
n = np.arange(1, N+1, 1) # integer progression n = 1,2,..,N

def power_law(const, slope): 
    """ 
    Calculate left side of the Equation (1), under the assumption :
        p_n = const * n^slope
    """
    pn = np.ones(N) * const * n**slope # calculate p_n as p_n = const * n^slope
    return np.prod(1. + pn) - Y/X 

pns = []
# find as many progressions as alphas
for alpha in alphas: 
    p0 = brentq(power_law, 0., 1., args=(alpha)) # solve equation
    pns.append(np.ones(N) * p0 * n**alpha)

# %% [markdown]
# ## Testa e mostra grafico

# %%
for i, pn in enumerate(pns):
    print 'p_n = %.2f * n^(%.1f); p_0 = %.2f perc, p_365 = %.2f perc' \
        % (pn[0], alphas[i], pn[0]*100, pn[-1]*100)
# Out:
# p_n = 0.77 * n^(-1.0); p_0 = 76.66 perc, p_365 = 0.21 perc
# p_n = 0.40 * n^(-0.8); p_0 = 40.23 perc, p_365 = 0.36 perc
# p_n = 0.19 * n^(-0.6); p_0 = 19.05 perc, p_365 = 0.55 perc
# p_n = 0.08 * n^(-0.4); p_0 = 8.24 perc, p_365 = 0.78 perc
# p_n = 0.03 * n^(-0.2); p_0 = 3.32 perc, p_365 = 1.02 perc

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams["axes.labelsize"] = 15
plt.rcParams["xtick.labelsize"] = 15
plt.rcParams["ytick.labelsize"] = 15
plt.rcParams["legend.fontsize"] = 15
fig, ax = plt.subplots()
ax.set_ylabel("% interessi [scala log]")
ax.set_xlabel("giorni")
for i, pn in enumerate(pns):
    ax.plot(n, pn*100., label="alpha=%.1f" % alphas[i])
ax.set_yscale('log')
ax.yaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False)
plt.show()

# %% [markdown]
# ## Stampa risultati

# %%
for n, alpha in enumerate(alphas):
    with open("danani_results/pn_alpha-%.1f.dat" % (-alpha), "w") as f:
        for p in pns[n]:
            print >>f, n, p
